# %%
import pandas as pd #linear algebra

# %%
import numpy as np #data processing

# %%
raw_data = pd.read_csv('Desktop/airline/train.csv') #input csv file
raw_data
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
#            Class  Flight Distance  Inflight wifi service  \
# 0       Eco Plus              460                      3
# 1       Business              235                      3
# 2       Business             1142                      2
# 3       Business              562                      2
# 4       Business              214                      3
# ...          ...              ...                    ...
# 103899       Eco              192                      2
# 103900  Business             2347                      4
# 103901  Business             1995                      1
# 103902       Eco             1000                      1
# 103903  Business             1723                      1
#
#         Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                       4  ...                       5
# 1                                       2  ...                       1
# 2                                       2  ...                       5
# 3                                       5  ...                       2
# 4                                       3  ...                       3
# ...                                   ...  ...                     ...
# 103899                                  1  ...                       2
# 103900                                  4  ...                       5
# 103901                                  1  ...                       4
# 103902                                  1  ...                       1
# 103903                                  3  ...                       1
#
#         On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                      4                 3                 4                4
# 1                      1                 5                 3                1
# 2                      4                 3                 4                4
# 3                      2                 5                 3                1
# 4                      3                 4                 4                3
# ...                  ...               ...               ...              ...
# 103899                 3                 1                 4                2
# 103900                 5                 5                 5                5
# 103901                 3                 2                 4                5
# 103902                 4                 5                 1                5
# 103903                 1                 1                 4                4
#
#         Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                      5            5                          25
# 1                      4            1                           1
# 2                      4            5                           0
# 3                      4            2                          11
# 4                      3            3                           0
# ...                  ...          ...                         ...
# 103899                 3            2                           3
# 103900                 5            4                           0
# 103901                 5            4                           7
# 103902                 4            1                           0
# 103903                 3            1                           0
#
#         Arrival Delay in Minutes             satisfaction
# 0                           18.0  neutral or dissatisfied
# 1                            6.0  neutral or dissatisfied
# 2                            0.0                satisfied
# 3                            9.0  neutral or dissatisfied
# 4                            0.0                satisfied
# ...                          ...                      ...
# 103899                       0.0  neutral or dissatisfied
# 103900                       0.0                satisfied
# 103901                      14.0  neutral or dissatisfied
# 103902                       0.0  neutral or dissatisfied
# 103903                       0.0  neutral or dissatisfied
#
# [103904 rows x 25 columns]

# %%
raw_data.info() #exploring my dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
#  11  Gate location                      103904 non-null  int64
#  12  Food and drink                     103904 non-null  int64
#  13  Online boarding                    103904 non-null  int64
#  14  Seat comfort                       103904 non-null  int64
#  15  Inflight entertainment             103904 non-null  int64
#  16  On-board service                   103904 non-null  int64
#  17  Leg room service                   103904 non-null  int64
#  18  Baggage handling                   103904 non-null  int64
#  19  Checkin service                    103904 non-null  int64
#  20  Inflight service                   103904 non-null  int64
#  21  Cleanliness                        103904 non-null  int64
#  22  Departure Delay in Minutes         103904 non-null  int64
#  23  Arrival Delay in Minutes           103594 non-null  float64
#  24  satisfaction                       103904 non-null  object
# dtypes: float64(1), int64(19), object(5)
# memory usage: 17.8+ MB

# %%
print(raw_data['id'].nunique())
# Out:
# 103904

# %%
raw_data= raw_data.drop(['Unnamed: 0', 'id'], axis=1) #did not provide any usefull information

# %%
raw_data.shape
# Out:
# (103904, 23)

# %%
raw_data.columns #usefull so I can copy paste them later
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
raw_data.isnull().sum() #checking for missing values
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# dtype: int64

# %%
raw_data.fillna(0,inplace=True) #replacing the nulls with zeros
raw_data.isnull().sum()
# Out:
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %%
raw_data['Departure - Arrival'] = abs(raw_data['Departure Delay in Minutes'] -raw_data['Arrival Delay in Minutes'])
#creating a new column with the absolute diffrence between departure and arrival delay. I assumpted the are correlated so I wanted to check that.

# %%
raw_data[['Departure Delay in Minutes','Arrival Delay in Minutes','Departure - Arrival']]
# Out:
#         Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                               25                      18.0
# 1                                1                       6.0
# 2                                0                       0.0
# 3                               11                       9.0
# 4                                0                       0.0
# ...                            ...                       ...
# 103899                           3                       0.0
# 103900                           0                       0.0
# 103901                           7                      14.0
# 103902                           0                       0.0
# 103903                           0                       0.0
#
#         Departure - Arrival
# 0                       7.0
# 1                       5.0
# 2                       0.0
# 3                       2.0
# 4                       0.0
# ...                     ...
# 103899                  3.0
# 103900                  0.0
# 103901                  7.0
# 103902                  0.0
# 103903                  0.0
#
# [103904 rows x 3 columns]

# %%
print(raw_data['Departure - Arrival'].mean()) #5 minutes diffrence by average
print(raw_data['Departure - Arrival'].std())
# Out:
# 5.070699876809362
# 9.593915755771414

# %%
raw_data= raw_data.drop(['Departure - Arrival'], axis=1) #I removed again the column

# %% [markdown]
# ## Filtering and grouping my data for deeper understanding
# ## Trying to find insights

# %%
raw_data['satisfaction'].describe()
# Out:
# count                      103904
# unique                          2
# top       neutral or dissatisfied
# freq                        58879
# Name: satisfaction, dtype: object

# %%
raw_data['Departure Delay in Minutes'].describe()
# Out:
# count    103904.000000
# mean         14.815618
# std          38.230901
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          12.000000
# max        1592.000000
# Name: Departure Delay in Minutes, dtype: float64

# %%
raw_data['Arrival Delay in Minutes'].describe()
# Out:
# count    103904.000000
# mean         15.133392
# std          38.649776
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          13.000000
# max        1584.000000
# Name: Arrival Delay in Minutes, dtype: float64

# %%
No_delay_arrival = raw_data['Arrival Delay in Minutes'] == 0
raw_data[No_delay_arrival]
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 2       Female     Loyal Customer   26  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# 5       Female     Loyal Customer   26  Personal Travel       Eco
# 7       Female     Loyal Customer   52  Business travel  Business
# 8       Female     Loyal Customer   41  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103898    Male     Loyal Customer   50  Personal Travel       Eco
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103900    Male     Loyal Customer   49  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
# 103903    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 2                  1142                      2
# 4                   214                      3
# 5                  1180                      3
# 7                  2035                      4
# 8                   853                      1
# ...                 ...                    ...
# 103898             1620                      3
# 103899              192                      2
# 103900             2347                      4
# 103902             1000                      1
# 103903             1723                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 2                                       2                       2
# 4                                       3                       3
# 5                                       4                       2
# 7                                       3                       4
# 8                                       2                       2
# ...                                   ...                     ...
# 103898                                  1                       3
# 103899                                  1                       2
# 103900                                  4                       4
# 103902                                  1                       1
# 103903                                  3                       3
#
#         Gate location  ...  On-board service  Leg room service  \
# 2                   2  ...                 4                 3
# 4                   3  ...                 3                 4
# 5                   1  ...                 3                 4
# 7                   4  ...                 5                 5
# 8                   2  ...                 1                 2
# ...               ...  ...               ...               ...
# 103898              4  ...                 4                 3
# 103899              3  ...                 3                 1
# 103900              4  ...                 5                 5
# 103902              5  ...                 4                 5
# 103903              3  ...                 1                 1
#
#         Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 2                      4                4                 4            5
# 4                      4                3                 3            3
# 5                      4                4                 4            1
# 7                      5                4                 5            4
# 8                      1                4                 1            2
# ...                  ...              ...               ...          ...
# 103898                 4                2                 4            2
# 103899                 4                2                 3            2
# 103900                 5                5                 5            4
# 103902                 1                5                 4            1
# 103903                 4                4                 3            1
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  \
# 2                                0                       0.0
# 4                                0                       0.0
# 5                                0                       0.0
# 7                                4                       0.0
# 8                                0                       0.0
# ...                            ...                       ...
# 103898                           0                       0.0
# 103899                           3                       0.0
# 103900                           0                       0.0
# 103902                           0                       0.0
# 103903                           0                       0.0
#
#                    satisfaction  Overall satisfaction rate
# 2                     satisfied                   3.714286
# 4                     satisfied                   3.500000
# 5       neutral or dissatisfied                   2.500000
# 7                     satisfied                   4.500000
# 8       neutral or dissatisfied                   2.071429
# ...                         ...                        ...
# 103898  neutral or dissatisfied                   2.785714
# 103899  neutral or dissatisfied                   2.214286
# 103900                satisfied                   4.357143
# 103902  neutral or dissatisfied                   2.285714
# 103903  neutral or dissatisfied                   2.000000
#
# [58469 rows x 24 columns]

# %%
Business_Class = raw_data['Class'] == 'Business' #Filter for just the bussiness class passengers

# %%
raw_data[Business_Class] #display only the business class

# %%
import sklearn
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
y = raw_data.satisfaction
ydict = {'neutral or dissatisfied':0, 'satisfied':1}
y = y.map(ydict)

# %%
a = raw_data.drop(columns='satisfaction')
x = a
x = pd.get_dummies(x, columns=['Gender','Customer Type', 'Type of Travel', 'Class'])

# %%
bestfeatures = SelectKBest(score_func=chi2, k=x.columns.size)
fit = bestfeatures.fit(x,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns) #concat the two df for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Attribute','Score']  #naming the dataframe columns
print(featureScores.nlargest(x.columns.size,'Score'))
# Out:
#                             Attribute         Score
# 1                     Flight Distance  7.753602e+06
# 17           Arrival Delay in Minutes  3.383326e+04
# 16         Departure Delay in Minutes  2.613488e+04
# 7                     Online boarding  1.476196e+04
# 23     Type of Travel_Personal Travel  1.444575e+04
# 24                     Class_Business  1.376929e+04
# 25                          Class_Eco  1.163229e+04
# 0                                 Age  1.134151e+04
# 9              Inflight entertainment  8.711182e+03
# 22     Type of Travel_Business travel  6.501444e+03
# 8                        Seat comfort  6.419260e+03
# 2               Inflight wifi service  5.422334e+03
# 10                   On-board service  5.299337e+03
# 11                   Leg room service  5.261977e+03
# 15                        Cleanliness  5.071376e+03
# 21    Customer Type_disloyal Customer  2.989976e+03
# 13                    Checkin service  2.808445e+03
# 6                      Food and drink  2.527913e+03
# 12                   Baggage handling  2.448815e+03
# 14                   Inflight service  2.362947e+03
# 4              Ease of Online booking  2.174525e+03
# 26                     Class_Eco Plus  1.070278e+03
# 20       Customer Type_Loyal Customer  6.682846e+02
# 3   Departure/Arrival time convenient  2.102601e+02
# 19                        Gender_Male  7.862399e+00
# 18                      Gender_Female  7.631270e+00
# 5                       Gate location  2.650173e-02

# %%
statistical_test = featureScores.nlargest(x.columns.size,'Score')
statistical_test.to_excel('Desktop/airline/statisticaltest.xlsx')

# %%
#filtering just the Business class
Business_Class_filter = raw_data['Class'] == 'Business'
Business_Class = raw_data[Business_Class_filter]

# %%
y = Business_Class.satisfaction 
ydict = {'neutral or dissatisfied':0, 'satisfied':1}
y = y.map(ydict)

# %%
b = Business_Class.drop(columns='satisfaction')
x = b
x = pd.get_dummies(x, columns=['Gender','Customer Type', 'Type of Travel', 'Class'])

# %%
bestfeatures = SelectKBest(score_func=chi2, k=x.columns.size)
fit = bestfeatures.fit(x,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Attribute','Score']  #naming the dataframe columns
print(featureScores.nlargest(x.columns.size,'Score'))  #print the best features
# Out:
#                             Attribute         Score
# 1                     Flight Distance  8.368600e+05
# 17           Arrival Delay in Minutes  1.744028e+04
# 16         Departure Delay in Minutes  1.354599e+04
# 9              Inflight entertainment  5.467841e+03
# 7                     Online boarding  5.227695e+03
# 11                   Leg room service  3.754634e+03
# 10                   On-board service  3.676391e+03
# 15                        Cleanliness  3.572493e+03
# 8                        Seat comfort  3.463656e+03
# 23     Type of Travel_Personal Travel  3.323130e+03
# 0                                 Age  3.201202e+03
# 21    Customer Type_disloyal Customer  3.093844e+03
# 12                   Baggage handling  2.351565e+03
# 14                   Inflight service  2.347836e+03
# 13                    Checkin service  2.231946e+03
# 6                      Food and drink  1.299487e+03
# 2               Inflight wifi service  1.164949e+03
# 20       Customer Type_Loyal Customer  5.379073e+02
# 4              Ease of Online booking  1.806192e+02
# 22     Type of Travel_Business travel  1.508797e+02
# 3   Departure/Arrival time convenient  1.359018e+01
# 19                        Gender_Male  1.495161e+00
# 18                      Gender_Female  1.483825e+00
# 5                       Gate location  1.775664e-01
# 24                     Class_Business  2.178941e-28

# %%
Business_flight_filter = raw_data['Type of Travel'] == 'Business travel'
Business_flight = raw_data[Business_flight_filter]

# %%
y = Business_flight.satisfaction
ydict = {'neutral or dissatisfied':0, 'satisfied':1}
y = y.map(ydict)

# %%
c = Business_flight.drop(columns='satisfaction')
x = c
x = pd.get_dummies(x, columns=['Gender','Customer Type', 'Type of Travel', 'Class'])

# %%
bestfeatures = SelectKBest(score_func=chi2, k=x.columns.size)
fit = bestfeatures.fit(x,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Attribute','Score']  #naming the dataframe columns
print(featureScores.nlargest(x.columns.size,'Score'))  #print the best features
# Out:
#                             Attribute         Score
# 1                     Flight Distance  3.477287e+06
# 17           Arrival Delay in Minutes  3.295809e+04
# 16         Departure Delay in Minutes  2.487074e+04
# 0                                 Age  1.193023e+04
# 7                     Online boarding  1.090429e+04
# 21    Customer Type_disloyal Customer  9.223922e+03
# 9              Inflight entertainment  8.561424e+03
# 24                          Class_Eco  6.832935e+03
# 10                   On-board service  6.517885e+03
# 8                        Seat comfort  6.395356e+03
# 15                        Cleanliness  5.686046e+03
# 11                   Leg room service  4.423504e+03
# 13                    Checkin service  4.388590e+03
# 23                     Class_Business  3.699950e+03
# 20       Customer Type_Loyal Customer  3.284881e+03
# 2               Inflight wifi service  3.259391e+03
# 12                   Baggage handling  3.171608e+03
# 14                   Inflight service  3.148844e+03
# 6                      Food and drink  2.662120e+03
# 25                     Class_Eco Plus  5.731123e+02
# 3   Departure/Arrival time convenient  5.209454e+02
# 4              Ease of Online booking  4.803633e+02
# 19                        Gender_Male  1.930728e+01
# 18                      Gender_Female  1.856677e+01
# 5                       Gate location  1.140111e+01
# 22     Type of Travel_Business travel  0.000000e+00

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import accuracy_score

# %%
raw_data['Flight Distance'].describe()
# Out:
# count    103904.000000
# mean       1189.448375
# std         997.147281
# min          31.000000
# 25%         414.000000
# 50%         843.000000
# 75%        1743.000000
# max        4983.000000
# Name: Flight Distance, dtype: float64

# %%
from scipy import stats

# %%
from scipy.stats import zscore

# %%
# %matplotlib inline

# %%
import statsmodels.api as sm

# %%
from statsmodels.formula.api import ols

# %%
raw_data.boxplot('Age', by='Gender')

# %%
raw_data.boxplot('Age', by='Class')

# %%
raw_data.boxplot('Online boarding', by='Class')

# %%
raw_data.boxplot('Online boarding', by='Type of Travel')

# %%
raw_data.boxplot('Cleanliness', by='Class')

# %%
raw_data.boxplot('Inflight entertainment', by='Class')

# %%
raw_data.boxplot('Departure/Arrival time convenient', by='Type of Travel')

# %%
Loyal_filter = raw_data['Customer Type'] == 'Loyal Customer'
loyal = raw_data[~Loyal_filter]

# %%
y = loyal.satisfaction
ydict = {'neutral or dissatisfied':0, 'satisfied':1}
y = y.map(ydict)

# %%
o = Business_flight.drop(columns='satisfaction')
x = o
x = pd.get_dummies(x, columns=['Gender','Customer Type', 'Type of Travel', 'Class'])

# %%
raw_data[raw_data['Class'] == 'Business'][['Type of Travel']].describe() 
#95% from Business class travelled for work purposes
# Out:
#          Type of Travel
# count             62160
# unique                2
# top     Business travel
# freq              59487

# %%
raw_data.sort_values('Age') #7min 85max
# Out:
#        Gender      Customer Type  Age   Type of Travel     Class  \
# 47527    Male     Loyal Customer    7  Personal Travel       Eco
# 79368    Male     Loyal Customer    7  Personal Travel  Eco Plus
# 79379  Female     Loyal Customer    7  Personal Travel       Eco
# 17770  Female     Loyal Customer    7  Personal Travel       Eco
# 47171    Male  disloyal Customer    7  Business travel       Eco
# ...       ...                ...  ...              ...       ...
# 37790  Female  disloyal Customer   85  Business travel  Business
# 15467  Female  disloyal Customer   85  Business travel  Business
# 31868  Female     Loyal Customer   85  Business travel  Eco Plus
# 19187    Male     Loyal Customer   85  Business travel  Business
# 35919  Female     Loyal Customer   85  Business travel  Business
#
#        Flight Distance  Inflight wifi service  \
# 47527              925                      2
# 79368              728                      3
# 79379             1092                      2
# 17770             1180                      4
# 47171              862                      3
# ...                ...                    ...
# 37790              899                      2
# 15467              101                      2
# 31868              147                      4
# 19187             3732                      3
# 35919             3156                      3
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# 47527                                  5                       2
# 79368                                  4                       3
# 79379                                  1                       2
# 17770                                  4                       4
# 47171                                  3                       3
# ...                                  ...                     ...
# 37790                                  2                       2
# 15467                                  2                       2
# 31868                                  4                       4
# 19187                                  4                       4
# 35919                                  5                       5
#
#        Gate location  ...  Inflight entertainment  On-board service  \
# 47527              1  ...                       3                 5
# 79368              3  ...                       5                 1
# 79379              2  ...                       2                 3
# 17770              2  ...                       3                 4
# 47171              3  ...                       4                 3
# ...              ...  ...                     ...               ...
# 37790              4  ...                       2                 3
# 15467              3  ...                       1                 2
# 31868              4  ...                       2                 1
# 19187              4  ...                       3                 3
# 35919              5  ...                       3                 1
#
#        Leg room service  Baggage handling  Checkin service  Inflight service  \
# 47527                 4                 2                1                 4
# 79368                 4                 3                3                 1
# 79379                 1                 2                1                 2
# 17770                 2                 4                5                 5
# 47171                 2                 4                2                 4
# ...                 ...               ...              ...               ...
# 37790                 4                 4                3                 3
# 15467                 2                 2                3                 2
# 31868                 3                 4                4                 1
# 19187                 3                 3                3                 3
# 35919                 4                 4                3                 3
#
#        Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 47527            3                           0                       1.0
# 79368            5                           0                      29.0
# 79379            2                          97                     120.0
# 17770            3                           0                       0.0
# 47171            4                           0                       9.0
# ...            ...                         ...                       ...
# 37790            3                           0                       0.0
# 15467            3                           0                       0.0
# 31868            4                           3                       0.0
# 19187            3                           1                       0.0
# 35919            3                           0                       0.0
#
#                   satisfaction
# 47527  neutral or dissatisfied
# 79368  neutral or dissatisfied
# 79379  neutral or dissatisfied
# 17770                satisfied
# 47171  neutral or dissatisfied
# ...                        ...
# 37790  neutral or dissatisfied
# 15467  neutral or dissatisfied
# 31868  neutral or dissatisfied
# 19187  neutral or dissatisfied
# 35919  neutral or dissatisfied
#
# [129880 rows x 23 columns]

# %%
Distance = raw_data[['Flight Distance']].describe()
Distance = Distance[1:].round(decimals=2)
Distance
# Out:
#       Flight Distance
# mean          1189.45
# std            997.15
# min             31.00
# 25%            414.00
# 50%            843.00
# 75%           1743.00
# max           4983.00

# %%
raw_data['Class'].value_counts() #which is the most popular class?
# Out:
# Business    49665
# Eco         46745
# Eco Plus     7494
# Name: Class, dtype: int64

# %%
raw_data['Gender'].value_counts() #men? women?
# Out:
# Female    65899
# Male      63981
# Name: Gender, dtype: int64

# %%
raw_data['Type of Travel'].value_counts()
# Out:
# Business travel    71655
# Personal Travel    32249
# Name: Type of Travel, dtype: int64

# %%
raw_data['satisfaction'].value_counts(normalize = True).round(decimals=3)
# Out:
# neutral or dissatisfied    0.567
# satisfied                  0.433
# Name: satisfaction, dtype: float64

# %%
raw_data['Cleanliness'].value_counts() #just selecting random attributes
# Out:
# 4    33969
# 3    30639
# 5    28416
# 2    20113
# 1    16729
# 0       14
# Name: Cleanliness, dtype: int64

# %%
raw_data['Inflight service'].value_counts()
# Out:
# 4    47323
# 5    34066
# 3    25316
# 2    14308
# 1     8862
# 0        5
# Name: Inflight service, dtype: int64

# %%
raw_data['Class'].value_counts(normalize = True).round(decimals=2)
# Out:
# Business    0.48
# Eco         0.45
# Eco Plus    0.07
# Name: Class, dtype: float64

# %%
raw_data['Gender'].value_counts(normalize = True).round(decimals=3)
# Out:
# Female    0.507
# Male      0.493
# Name: Gender, dtype: float64

# %%
raw_data['Gender'].value_counts(normalize = True).round(decimals=3)

# %%
raw_data['Type of Travel'].value_counts(normalize = True).round(decimals=3)
# Out:
# Business travel    0.69
# Personal Travel    0.31
# Name: Type of Travel, dtype: float64

# %%
raw_data['Customer Type'].value_counts(normalize = True).round(decimals=3)
# Out:
# Loyal Customer       0.817
# disloyal Customer    0.183
# Name: Customer Type, dtype: float64

# %%
raw_data['Cleanliness'].value_counts(normalize = True)
# Out:
# 4    0.261541
# 3    0.235902
# 5    0.218787
# 2    0.154858
# 1    0.128804
# 0    0.000108
# Name: Cleanliness, dtype: float64

# %%
raw_data['Cleanliness'].mean()
# Out:
# 3.286325839236218

# %%
raw_data.groupby('Gender').mean()['Age'].round(decimals=2)
# Out:
# Gender
# Female    39.29
# Male      39.57
# Name: Age, dtype: float64

# %%
raw_data.groupby('Gender').mean()[['Age','Ease of Online booking']]
# Out:
#               Age  Ease of Online booking
# Gender
# Female  39.293935                2.748737
# Male    39.565996                2.765258

# %%
raw_data.groupby(['Gender','Class']).mean()[['Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness']].round(decimals=2)
# Out:
#                  Inflight wifi service  Departure/Arrival time convenient  \
# Gender Class
# Female Business                   2.77                               2.91
#        Eco                        2.66                               3.17
#        Eco Plus                   2.74                               3.15
# Male   Business                   2.78                               2.91
#        Eco                        2.69                               3.22
#        Eco Plus                   2.78                               3.27
#
#                  Ease of Online booking  Gate location  Food and drink  \
# Gender Class
# Female Business                    2.91           2.99            3.32
#        Eco                         2.59           2.97            3.09
#        Eco Plus                    2.64           2.98            3.10
# Male   Business                    2.92           2.98            3.34
#        Eco                         2.61           2.97            3.08
#        Eco Plus                    2.69           2.96            3.12
#
#                  Online boarding  Seat comfort  Inflight entertainment  \
# Gender Class
# Female Business             3.71          3.76                    3.64
#        Eco                  2.95          3.23                    3.09
#        Eco Plus             2.98          3.24                    3.11
# Male   Business             3.73          3.77                    3.64
#        Eco                  2.68          3.05                    3.10
#        Eco Plus             2.78          3.09                    3.13
#
#                  On-board service  Leg room service  Baggage handling  \
# Gender Class
# Female Business              3.68              3.65              3.85
#        Eco                   3.10              3.01              3.37
#        Eco Plus              3.06              3.00              3.28
# Male   Business              3.68              3.64              3.84
#        Eco                   3.14              3.17              3.53
#        Eco Plus              3.01              3.12              3.43
#
#                  Checkin service  Inflight service  Cleanliness
# Gender Class
# Female Business             3.52              3.85         3.47
#        Eco                  3.11              3.38         3.11
#        Eco Plus             3.03              3.31         3.11
# Male   Business             3.52              3.84         3.49
#        Eco                  3.14              3.56         3.10
#        Eco Plus             3.00              3.47         3.13

# %%
satisfied = raw_data['satisfaction']=='satisfied'

# %%
raw_data[satisfied]
# Out:
#        Gender   Customer Type  Age   Type of Travel     Class  \
# 2      Female  Loyal Customer   26  Business travel  Business
# 4        Male  Loyal Customer   61  Business travel  Business
# 7      Female  Loyal Customer   52  Business travel  Business
# 13       Male  Loyal Customer   33  Personal Travel       Eco
# 16     Female  Loyal Customer   26  Business travel  Business
# ...       ...             ...  ...              ...       ...
# 25956  Female  Loyal Customer   29  Business travel  Business
# 25961    Male  Loyal Customer   51  Business travel  Business
# 25969    Male  Loyal Customer   52  Business travel  Business
# 25972    Male  Loyal Customer   23  Business travel  Business
# 25974    Male  Loyal Customer   14  Business travel  Business
#
#        Flight Distance  Inflight wifi service  \
# 2                 1142                      2
# 4                  214                      3
# 7                 2035                      4
# 13                 946                      4
# 16                2123                      3
# ...                ...                    ...
# 25956             2864                      5
# 25961             2296                      3
# 25969              280                      3
# 25972              646                      4
# 25974             1127                      3
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# 2                                      2                       2
# 4                                      3                       3
# 7                                      3                       4
# 13                                     2                       4
# 16                                     3                       3
# ...                                  ...                     ...
# 25956                                  5                       5
# 25961                                  3                       3
# 25969                                  3                       3
# 25972                                  4                       4
# 25974                                  3                       3
#
#        Gate location  ...  Inflight entertainment  On-board service  \
# 2                  2  ...                       5                 4
# 4                  3  ...                       3                 3
# 7                  4  ...                       5                 5
# 13                 3  ...                       4                 4
# 16                 3  ...                       4                 5
# ...              ...  ...                     ...               ...
# 25956              5  ...                       3                 5
# 25961              3  ...                       5                 5
# 25969              3  ...                       4                 4
# 25972              4  ...                       4                 4
# 25974              3  ...                       4                 3
#
#        Leg room service  Baggage handling  Checkin service  Inflight service  \
# 2                     3                 4                4                 4
# 4                     4                 4                3                 3
# 7                     5                 5                4                 5
# 13                    5                 2                2                 2
# 16                    3                 4                5                 4
# ...                 ...               ...              ...               ...
# 25956                 5                 5                3                 5
# 25961                 5                 5                3                 5
# 25969                 4                 4                3                 4
# 25972                 5                 5                5                 5
# 25974                 2                 5                4                 5
#
#        Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 2                5                           0                       0.0
# 4                3                           0                       0.0
# 7                4                           4                       0.0
# 13               4                           0                       0.0
# 16               4                          49                      51.0
# ...            ...                         ...                       ...
# 25956            3                           0                       0.0
# 25961            3                           2                       0.0
# 25969            3                           0                       0.0
# 25972            4                           0                       0.0
# 25974            4                           0                       0.0
#
#        satisfaction
# 2         satisfied
# 4         satisfied
# 7         satisfied
# 13        satisfied
# 16        satisfied
# ...             ...
# 25956     satisfied
# 25961     satisfied
# 25969     satisfied
# 25972     satisfied
# 25974     satisfied
#
# [56428 rows x 23 columns]

# %%
raw_data.describe()[['Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness']]
# Out:
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          129880.000000                      129880.000000
# mean                2.728696                           3.057599
# std                 1.329340                           1.526741
# min                 0.000000                           0.000000
# 25%                 2.000000                           2.000000
# 50%                 3.000000                           3.000000
# 75%                 4.000000                           4.000000
# max                 5.000000                           5.000000
#
#        Ease of Online booking  Gate location  Food and drink  Online boarding  \
# count           129880.000000  129880.000000   129880.000000    129880.000000
# mean                 2.756876       2.976925        3.204774         3.252633
# std                  1.401740       1.278520        1.329933         1.350719
# min                  0.000000       0.000000        0.000000         0.000000
# 25%                  2.000000       2.000000        2.000000         2.000000
# 50%                  3.000000       3.000000        3.000000         3.000000
# 75%                  4.000000       4.000000        4.000000         4.000000
# max                  5.000000       5.000000        5.000000         5.000000
#
#         Seat comfort  Inflight entertainment  On-board service  \
# count  129880.000000           129880.000000     129880.000000
# mean        3.441361                3.358077          3.383023
# std         1.319289                1.334049          1.287099
# min         0.000000                0.000000          0.000000
# 25%         2.000000                2.000000          2.000000
# 50%         4.000000                4.000000          4.000000
# 75%         5.000000                4.000000          4.000000
# max         5.000000                5.000000          5.000000
#
#        Leg room service  Baggage handling  Checkin service  Inflight service  \
# count     129880.000000     129880.000000    129880.000000     129880.000000
# mean           3.350878          3.632114         3.306267          3.642193
# std            1.316252          1.180025         1.266185          1.176669
# min            0.000000          1.000000         0.000000          0.000000
# 25%            2.000000          3.000000         3.000000          3.000000
# 50%            4.000000          4.000000         3.000000          4.000000
# 75%            4.000000          5.000000         4.000000          5.000000
# max            5.000000          5.000000         5.000000          5.000000
#
#          Cleanliness
# count  129880.000000
# mean        3.286326
# std         1.313682
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000

# %%
quality_variables = raw_data.describe()[['Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness']]

# %%
quality_variables[1:]
# Out:
#       Inflight wifi service  Departure/Arrival time convenient  \
# mean               2.729683                           3.060296
# std                1.327829                           1.525075
# min                0.000000                           0.000000
# 25%                2.000000                           2.000000
# 50%                3.000000                           3.000000
# 75%                4.000000                           4.000000
# max                5.000000                           5.000000
#
#       Ease of Online booking  Gate location  Food and drink  Online boarding  \
# mean                2.756901       2.976883        3.202129         3.250375
# std                 1.398929       1.277621        1.329533         1.349509
# min                 0.000000       0.000000        0.000000         0.000000
# 25%                 2.000000       2.000000        2.000000         2.000000
# 50%                 3.000000       3.000000        3.000000         3.000000
# 75%                 4.000000       4.000000        4.000000         4.000000
# max                 5.000000       5.000000        5.000000         5.000000
#
#       Seat comfort  Inflight entertainment  On-board service  \
# mean      3.439396                3.358158          3.382363
# std       1.319088                1.332991          1.288354
# min       0.000000                0.000000          0.000000
# 25%       2.000000                2.000000          2.000000
# 50%       4.000000                4.000000          4.000000
# 75%       5.000000                4.000000          4.000000
# max       5.000000                5.000000          5.000000
#
#       Leg room service  Baggage handling  Checkin service  Inflight service  \
# mean          3.351055          3.631833         3.304290          3.640428
# std           1.315605          1.180903         1.265396          1.175663
# min           0.000000          1.000000         0.000000          0.000000
# 25%           2.000000          3.000000         3.000000          3.000000
# 50%           4.000000          4.000000         3.000000          4.000000
# 75%           4.000000          5.000000         4.000000          5.000000
# max           5.000000          5.000000         5.000000          5.000000
#
#       Cleanliness
# mean     3.286351
# std      1.312273
# min      0.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000

# %%
quality_variables.to_excel('Desktop/airline/rating.xlsx')

# %%
quality_var = raw_data[['Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness']]

# %%
quality_var_corr = quality_var.corr(method='pearson')
quality_var_corr
# Out:
#                                    Inflight wifi service  \
# Inflight wifi service                           1.000000
# Departure/Arrival time convenient               0.987940
# Ease of Online booking                          0.999626
# Gate location                                   0.993799
# Food and drink                                  0.976587
# Online boarding                                 0.971751
# Seat comfort                                   -0.339241
# Inflight entertainment                          0.137446
# On-board service                                0.096884
# Leg room service                                0.124955
# Baggage handling                               -0.612455
# Checkin service                                 0.549780
# Inflight service                               -0.894445
# Cleanliness                                     0.966511
#
#                                    Departure/Arrival time convenient  \
# Inflight wifi service                                       0.987940
# Departure/Arrival time convenient                           1.000000
# Ease of Online booking                                      0.991255
# Gate location                                               0.996778
# Food and drink                                              0.995955
# Online boarding                                             0.994541
# Seat comfort                                               -0.312473
# Inflight entertainment                                      0.210802
# On-board service                                            0.171558
# Leg room service                                            0.197853
# Baggage handling                                           -0.689008
# Checkin service                                             0.533702
# Inflight service                                           -0.901902
# Cleanliness                                                 0.991677
#
#                                    Ease of Online booking  Gate location  \
# Inflight wifi service                            0.999626       0.993799
# Departure/Arrival time convenient                0.991255       0.996778
# Ease of Online booking                           1.000000       0.994986
# Gate location                                    0.994986       1.000000
# Food and drink                                   0.979981       0.994165
# Online boarding                                  0.975645       0.991534
# Seat comfort                                    -0.332896      -0.334117
# Inflight entertainment                           0.152660       0.168175
# On-board service                                 0.112049       0.129166
# Leg room service                                 0.140053       0.155493
# Baggage handling                                -0.632521      -0.630876
# Checkin service                                  0.543763       0.558249
# Inflight service                                -0.899022      -0.891683
# Cleanliness                                      0.970509       0.988804
#
#                                    Food and drink  Online boarding  \
# Inflight wifi service                    0.976587         0.971751
# Departure/Arrival time convenient        0.995955         0.994541
# Ease of Online booking                   0.979981         0.975645
# Gate location                            0.994165         0.991534
# Food and drink                           1.000000         0.999751
# Online boarding                          0.999751         1.000000
# Seat comfort                            -0.317287        -0.312738
# Inflight entertainment                   0.210531         0.220015
# On-board service                         0.173083         0.182899
# Leg room service                         0.197696         0.207158
# Baggage handling                        -0.665304        -0.673366
# Checkin service                          0.549295         0.545750
# Inflight service                        -0.885270        -0.883289
# Cleanliness                              0.999073         0.999698
#
#                                    Seat comfort  Inflight entertainment  \
# Inflight wifi service                 -0.339241                0.137446
# Departure/Arrival time convenient     -0.312473                0.210802
# Ease of Online booking                -0.332896                0.152660
# Gate location                         -0.334117                0.168175
# Food and drink                        -0.317287                0.210531
# Online boarding                       -0.312738                0.220015
# Seat comfort                           1.000000                0.612516
# Inflight entertainment                 0.612516                1.000000
# On-board service                       0.628915                0.999035
# Leg room service                       0.619012                0.999900
# Baggage handling                       0.036932               -0.509274
# Checkin service                       -0.906608               -0.558054
# Inflight service                       0.341245               -0.298708
# Cleanliness                           -0.312589                0.221311
#
#                                    On-board service  Leg room service  \
# Inflight wifi service                      0.096884          0.124955
# Departure/Arrival time convenient          0.171558          0.197853
# Ease of Online booking                     0.112049          0.140053
# Gate location                              0.129166          0.155493
# Food and drink                             0.173083          0.197696
# Online boarding                            0.182899          0.207158
# Seat comfort                               0.628915          0.619012
# Inflight entertainment                     0.999035          0.999900
# On-board service                           1.000000          0.999485
# Leg room service                           0.999485          1.000000
# Baggage handling                          -0.479601         -0.498445
# Checkin service                           -0.580657         -0.567164
# Inflight service                          -0.261499         -0.287215
# Cleanliness                                0.184756          0.208498
#
#                                    Baggage handling  Checkin service  \
# Inflight wifi service                     -0.612455         0.549780
# Departure/Arrival time convenient         -0.689008         0.533702
# Ease of Online booking                    -0.632521         0.543763
# Gate location                             -0.630876         0.558249
# Food and drink                            -0.665304         0.549295
# Online boarding                           -0.673366         0.545750
# Seat comfort                               0.036932        -0.906608
# Inflight entertainment                    -0.509274        -0.558054
# On-board service                          -0.479601        -0.580657
# Leg room service                          -0.498445        -0.567164
# Baggage handling                           1.000000        -0.155371
# Checkin service                           -0.155371         1.000000
# Inflight service                           0.681014        -0.389881
# Cleanliness                               -0.667929         0.548046
#
#                                    Inflight service  Cleanliness
# Inflight wifi service                     -0.894445     0.966511
# Departure/Arrival time convenient         -0.901902     0.991677
# Ease of Online booking                    -0.899022     0.970509
# Gate location                             -0.891683     0.988804
# Food and drink                            -0.885270     0.999073
# Online boarding                           -0.883289     0.999698
# Seat comfort                               0.341245    -0.312589
# Inflight entertainment                    -0.298708     0.221311
# On-board service                          -0.261499     0.184756
# Leg room service                          -0.287215     0.208498
# Baggage handling                           0.681014    -0.667929
# Checkin service                           -0.389881     0.548046
# Inflight service                           1.000000    -0.877418
# Cleanliness                               -0.877418     1.000000

# %%
sn.heatmap(quality_var_corr, cmap='coolwarm')

# %%
quality_variables.iloc[1:3]
# Out:
#       Inflight wifi service  Departure/Arrival time convenient  \
# mean               2.728696                           3.057599
# std                1.329340                           1.526741
#
#       Ease of Online booking  Gate location  Food and drink  Online boarding  \
# mean                2.756876       2.976925        3.204774         3.252633
# std                 1.401740       1.278520        1.329933         1.350719
#
#       Seat comfort  Inflight entertainment  On-board service  \
# mean      3.441361                3.358077          3.383023
# std       1.319289                1.334049          1.287099
#
#       Leg room service  Baggage handling  Checkin service  Inflight service  \
# mean          3.350878          3.632114         3.306267          3.642193
# std           1.316252          1.180025         1.266185          1.176669
#
#       Cleanliness
# mean     3.286326
# std      1.313682

# %%
quality_variables_mean_std = quality_variables.iloc[1:3].round(decimals=2)

# %%
quality_variables_mean_std
# Out:
#       Inflight wifi service  Departure/Arrival time convenient  \
# mean                   2.73                               3.06
# std                    1.33                               1.53
#
#       Ease of Online booking  Gate location  Food and drink  Online boarding  \
# mean                    2.76           2.98            3.20             3.25
# std                     1.40           1.28            1.33             1.35
#
#       Seat comfort  Inflight entertainment  On-board service  \
# mean          3.44                    3.36              3.38
# std           1.32                    1.33              1.29
#
#       Leg room service  Baggage handling  Checkin service  Inflight service  \
# mean              3.35              3.63             3.31              3.64
# std               1.32              1.18             1.27              1.18
#
#       Cleanliness
# mean         3.29
# std          1.31

# %%
quality_variables_mean_std.idxmax(axis=1)
# Out:
# mean                     Inflight service
# std     Departure/Arrival time convenient
# dtype: object

# %%
quality_variables_mean_std.max(axis=1)
# Out:
# mean    3.64
# std     1.53
# dtype: float64

# %%
Loyal_Customers = raw_data['Customer Type']=='Loyal Customer' 
#filtering Loyal customers

# %%
raw_data['Customer Type'].value_counts()
# Out:
# Loyal Customer       84923
# disloyal Customer    18981
# Name: Customer Type, dtype: int64

# %%
raw_data['Customer Type'].value_counts(normalize = True).round(decimals=2)
# Out:
# Loyal Customer       0.82
# disloyal Customer    0.18
# Name: Customer Type, dtype: float64

# %%
raw_data[Loyal_Customers].groupby('satisfaction').size()
# Out:
# satisfaction
# neutral or dissatisfied    44390
# satisfied                  40533
# dtype: int64

# %%
raw_data[Loyal_Customers].groupby('satisfaction').size().add_prefix('Loyal Customers: ')
# Out:
# satisfaction
# Loyal Customers: neutral or dissatisfied    44390
# Loyal Customers: satisfied                  40533
# dtype: int64

# %%
Loyal_Satisfied_Customers =(raw_data['Customer Type']=='Loyal Customer') & (raw_data['satisfaction']=='satisfied')

# %%
raw_data[~Loyal_Customers].groupby('satisfaction').size().add_prefix('Disloyal Customers: ')
# Out:
# satisfaction
# Disloyal Customers: neutral or dissatisfied    14489
# Disloyal Customers: satisfied                   4492
# dtype: int64

# %%
#Hypothesis: The loyal customers should be satisfied in a higher percentage than the disloyal customers. 
#True: On loyal customers 47.72% are satisfied while in the disloyal only 23.66% are satisfied.

# %%
raw_data.corr(method='pearson').round(decimals=2)
# Out:
#                                     Age  Flight Distance  \
# Age                                1.00             0.10
# Flight Distance                    0.10             1.00
# Inflight wifi service              0.02             0.01
# Departure/Arrival time convenient  0.04            -0.02
# Ease of Online booking             0.02             0.07
# Gate location                     -0.00             0.00
# Food and drink                     0.02             0.06
# Online boarding                    0.21             0.21
# Seat comfort                       0.16             0.16
# Inflight entertainment             0.08             0.13
# On-board service                   0.06             0.11
# Leg room service                   0.04             0.13
# Baggage handling                  -0.05             0.06
# Checkin service                    0.04             0.07
# Inflight service                  -0.05             0.06
# Cleanliness                        0.05             0.09
# Departure Delay in Minutes        -0.01             0.00
# Arrival Delay in Minutes          -0.01            -0.00
# Departure delay - Arrival delay   -0.01             0.03
# Overall satisfaction rate          0.09             0.16
#
#                                    Inflight wifi service  \
# Age                                                 0.02
# Flight Distance                                     0.01
# Inflight wifi service                               1.00
# Departure/Arrival time convenient                   0.34
# Ease of Online booking                              0.72
# Gate location                                       0.34
# Food and drink                                      0.13
# Online boarding                                     0.46
# Seat comfort                                        0.12
# Inflight entertainment                              0.21
# On-board service                                    0.12
# Leg room service                                    0.16
# Baggage handling                                    0.12
# Checkin service                                     0.04
# Inflight service                                    0.11
# Cleanliness                                         0.13
# Departure Delay in Minutes                         -0.02
# Arrival Delay in Minutes                           -0.02
# Departure delay - Arrival delay                    -0.02
# Overall satisfaction rate                           0.58
#
#                                    Departure/Arrival time convenient  \
# Age                                                             0.04
# Flight Distance                                                -0.02
# Inflight wifi service                                           0.34
# Departure/Arrival time convenient                               1.00
# Ease of Online booking                                          0.44
# Gate location                                                   0.44
# Food and drink                                                  0.00
# Online boarding                                                 0.07
# Seat comfort                                                    0.01
# Inflight entertainment                                         -0.00
# On-board service                                                0.07
# Leg room service                                                0.01
# Baggage handling                                                0.07
# Checkin service                                                 0.09
# Inflight service                                                0.07
# Cleanliness                                                     0.01
# Departure Delay in Minutes                                      0.00
# Arrival Delay in Minutes                                       -0.00
# Departure delay - Arrival delay                                 0.00
# Overall satisfaction rate                                       0.40
#
#                                    Ease of Online booking  Gate location  \
# Age                                                  0.02          -0.00
# Flight Distance                                      0.07           0.00
# Inflight wifi service                                0.72           0.34
# Departure/Arrival time convenient                    0.44           0.44
# Ease of Online booking                               1.00           0.46
# Gate location                                        0.46           1.00
# Food and drink                                       0.03          -0.00
# Online boarding                                      0.40           0.00
# Seat comfort                                         0.03           0.00
# Inflight entertainment                               0.05           0.00
# On-board service                                     0.04          -0.03
# Leg room service                                     0.11          -0.01
# Baggage handling                                     0.04           0.00
# Checkin service                                      0.01          -0.04
# Inflight service                                     0.04           0.00
# Cleanliness                                          0.02          -0.00
# Departure Delay in Minutes                          -0.01           0.01
# Arrival Delay in Minutes                            -0.01           0.01
# Departure delay - Arrival delay                     -0.00           0.00
# Overall satisfaction rate                            0.50           0.32
#
#                                    Food and drink  Online boarding  \
# Age                                          0.02             0.21
# Flight Distance                              0.06             0.21
# Inflight wifi service                        0.13             0.46
# Departure/Arrival time convenient            0.00             0.07
# Ease of Online booking                       0.03             0.40
# Gate location                               -0.00             0.00
# Food and drink                               1.00             0.23
# Online boarding                              0.23             1.00
# Seat comfort                                 0.57             0.42
# Inflight entertainment                       0.62             0.29
# On-board service                             0.06             0.16
# Leg room service                             0.03             0.12
# Baggage handling                             0.03             0.08
# Checkin service                              0.09             0.20
# Inflight service                             0.03             0.07
# Cleanliness                                  0.66             0.33
# Departure Delay in Minutes                  -0.03            -0.02
# Arrival Delay in Minutes                    -0.03            -0.02
# Departure delay - Arrival delay             -0.02            -0.02
# Overall satisfaction rate                    0.50             0.55
#
#                                    Seat comfort  Inflight entertainment  \
# Age                                        0.16                    0.08
# Flight Distance                            0.16                    0.13
# Inflight wifi service                      0.12                    0.21
# Departure/Arrival time convenient          0.01                   -0.00
# Ease of Online booking                     0.03                    0.05
# Gate location                              0.00                    0.00
# Food and drink                             0.57                    0.62
# Online boarding                            0.42                    0.29
# Seat comfort                               1.00                    0.61
# Inflight entertainment                     0.61                    1.00
# On-board service                           0.13                    0.42
# Leg room service                           0.11                    0.30
# Baggage handling                           0.07                    0.38
# Checkin service                            0.19                    0.12
# Inflight service                           0.07                    0.40
# Cleanliness                                0.68                    0.69
# Departure Delay in Minutes                -0.03                   -0.03
# Arrival Delay in Minutes                  -0.03                   -0.03
# Departure delay - Arrival delay           -0.02                   -0.02
# Overall satisfaction rate                  0.57                    0.71
#
#                                    On-board service  Leg room service  \
# Age                                            0.06              0.04
# Flight Distance                                0.11              0.13
# Inflight wifi service                          0.12              0.16
# Departure/Arrival time convenient              0.07              0.01
# Ease of Online booking                         0.04              0.11
# Gate location                                 -0.03             -0.01
# Food and drink                                 0.06              0.03
# Online boarding                                0.16              0.12
# Seat comfort                                   0.13              0.11
# Inflight entertainment                         0.42              0.30
# On-board service                               1.00              0.36
# Leg room service                               0.36              1.00
# Baggage handling                               0.52              0.37
# Checkin service                                0.24              0.15
# Inflight service                               0.55              0.37
# Cleanliness                                    0.12              0.10
# Departure Delay in Minutes                    -0.03              0.01
# Arrival Delay in Minutes                      -0.04              0.01
# Departure delay - Arrival delay               -0.03             -0.01
# Overall satisfaction rate                      0.52              0.44
#
#                                    Baggage handling  Checkin service  \
# Age                                           -0.05             0.04
# Flight Distance                                0.06             0.07
# Inflight wifi service                          0.12             0.04
# Departure/Arrival time convenient              0.07             0.09
# Ease of Online booking                         0.04             0.01
# Gate location                                  0.00            -0.04
# Food and drink                                 0.03             0.09
# Online boarding                                0.08             0.20
# Seat comfort                                   0.07             0.19
# Inflight entertainment                         0.38             0.12
# On-board service                               0.52             0.24
# Leg room service                               0.37             0.15
# Baggage handling                               1.00             0.23
# Checkin service                                0.23             1.00
# Inflight service                               0.63             0.24
# Cleanliness                                    0.10             0.18
# Departure Delay in Minutes                    -0.01            -0.02
# Arrival Delay in Minutes                      -0.01            -0.02
# Departure delay - Arrival delay               -0.01            -0.02
# Overall satisfaction rate                      0.49             0.38
#
#                                    Inflight service  Cleanliness  \
# Age                                           -0.05         0.05
# Flight Distance                                0.06         0.09
# Inflight wifi service                          0.11         0.13
# Departure/Arrival time convenient              0.07         0.01
# Ease of Online booking                         0.04         0.02
# Gate location                                  0.00        -0.00
# Food and drink                                 0.03         0.66
# Online boarding                                0.07         0.33
# Seat comfort                                   0.07         0.68
# Inflight entertainment                         0.40         0.69
# On-board service                               0.55         0.12
# Leg room service                               0.37         0.10
# Baggage handling                               0.63         0.10
# Checkin service                                0.24         0.18
# Inflight service                               1.00         0.09
# Cleanliness                                    0.09         1.00
# Departure Delay in Minutes                    -0.05        -0.01
# Arrival Delay in Minutes                      -0.06        -0.02
# Departure delay - Arrival delay               -0.03        -0.02
# Overall satisfaction rate                      0.50         0.58
#
#                                    Departure Delay in Minutes  \
# Age                                                     -0.01
# Flight Distance                                          0.00
# Inflight wifi service                                   -0.02
# Departure/Arrival time convenient                        0.00
# Ease of Online booking                                  -0.01
# Gate location                                            0.01
# Food and drink                                          -0.03
# Online boarding                                         -0.02
# Seat comfort                                            -0.03
# Inflight entertainment                                  -0.03
# On-board service                                        -0.03
# Leg room service                                         0.01
# Baggage handling                                        -0.01
# Checkin service                                         -0.02
# Inflight service                                        -0.05
# Cleanliness                                             -0.01
# Departure Delay in Minutes                               1.00
# Arrival Delay in Minutes                                 0.96
# Departure delay - Arrival delay                          0.33
# Overall satisfaction rate                               -0.03
#
#                                    Arrival Delay in Minutes  \
# Age                                                   -0.01
# Flight Distance                                       -0.00
# Inflight wifi service                                 -0.02
# Departure/Arrival time convenient                     -0.00
# Ease of Online booking                                -0.01
# Gate location                                          0.01
# Food and drink                                        -0.03
# Online boarding                                       -0.02
# Seat comfort                                          -0.03
# Inflight entertainment                                -0.03
# On-board service                                      -0.04
# Leg room service                                       0.01
# Baggage handling                                      -0.01
# Checkin service                                       -0.02
# Inflight service                                      -0.06
# Cleanliness                                           -0.02
# Departure Delay in Minutes                             0.96
# Arrival Delay in Minutes                               1.00
# Departure delay - Arrival delay                        0.40
# Overall satisfaction rate                             -0.04
#
#                                    Departure delay - Arrival delay  \
# Age                                                          -0.01
# Flight Distance                                               0.03
# Inflight wifi service                                        -0.02
# Departure/Arrival time convenient                             0.00
# Ease of Online booking                                       -0.00
# Gate location                                                 0.00
# Food and drink                                               -0.02
# Online boarding                                              -0.02
# Seat comfort                                                 -0.02
# Inflight entertainment                                       -0.02
# On-board service                                             -0.03
# Leg room service                                             -0.01
# Baggage handling                                             -0.01
# Checkin service                                              -0.02
# Inflight service                                             -0.03
# Cleanliness                                                  -0.02
# Departure Delay in Minutes                                    0.33
# Arrival Delay in Minutes                                      0.40
# Departure delay - Arrival delay                               1.00
# Overall satisfaction rate                                    -0.03
#
#                                    Overall satisfaction rate
# Age                                                     0.09
# Flight Distance                                         0.16
# Inflight wifi service                                   0.58
# Departure/Arrival time convenient                       0.40
# Ease of Online booking                                  0.50
# Gate location                                           0.32
# Food and drink                                          0.50
# Online boarding                                         0.55
# Seat comfort                                            0.57
# Inflight entertainment                                  0.71
# On-board service                                        0.52
# Leg room service                                        0.44
# Baggage handling                                        0.49
# Checkin service                                         0.38
# Inflight service                                        0.50
# Cleanliness                                             0.58
# Departure Delay in Minutes                             -0.03
# Arrival Delay in Minutes                               -0.04
# Departure delay - Arrival delay                        -0.03
# Overall satisfaction rate                               1.00

# %%
raw_data.corr()
# Out:
#                                         Age  Flight Distance  \
# Age                                1.000000         0.099461
# Flight Distance                    0.099461         1.000000
# Inflight wifi service              0.017859         0.007131
# Departure/Arrival time convenient  0.038125        -0.020043
# Ease of Online booking             0.024842         0.065717
# Gate location                     -0.001330         0.004793
# Food and drink                     0.023000         0.056994
# Online boarding                    0.208939         0.214869
# Seat comfort                       0.160277         0.157333
# Inflight entertainment             0.076444         0.128740
# On-board service                   0.057594         0.109526
# Leg room service                   0.040583         0.133916
# Baggage handling                  -0.047529         0.063184
# Checkin service                    0.035482         0.073072
# Inflight service                  -0.049427         0.057540
# Cleanliness                        0.053611         0.093149
# Departure Delay in Minutes        -0.010152         0.002158
# Arrival Delay in Minutes          -0.012105        -0.002470
#
#                                    Inflight wifi service  \
# Age                                             0.017859
# Flight Distance                                 0.007131
# Inflight wifi service                           1.000000
# Departure/Arrival time convenient               0.343845
# Ease of Online booking                          0.715856
# Gate location                                   0.336248
# Food and drink                                  0.134718
# Online boarding                                 0.456970
# Seat comfort                                    0.122658
# Inflight entertainment                          0.209321
# On-board service                                0.121500
# Leg room service                                0.160473
# Baggage handling                                0.120923
# Checkin service                                 0.043193
# Inflight service                                0.110441
# Cleanliness                                     0.132698
# Departure Delay in Minutes                     -0.017402
# Arrival Delay in Minutes                       -0.019042
#
#                                    Departure/Arrival time convenient  \
# Age                                                         0.038125
# Flight Distance                                            -0.020043
# Inflight wifi service                                       0.343845
# Departure/Arrival time convenient                           1.000000
# Ease of Online booking                                      0.436961
# Gate location                                               0.444757
# Food and drink                                              0.004906
# Online boarding                                             0.070119
# Seat comfort                                                0.011344
# Inflight entertainment                                     -0.004861
# On-board service                                            0.068882
# Leg room service                                            0.012441
# Baggage handling                                            0.072126
# Checkin service                                             0.093333
# Inflight service                                            0.073318
# Cleanliness                                                 0.014292
# Departure Delay in Minutes                                  0.001005
# Arrival Delay in Minutes                                   -0.000918
#
#                                    Ease of Online booking  Gate location  \
# Age                                              0.024842      -0.001330
# Flight Distance                                  0.065717       0.004793
# Inflight wifi service                            0.715856       0.336248
# Departure/Arrival time convenient                0.436961       0.444757
# Ease of Online booking                           1.000000       0.458655
# Gate location                                    0.458655       1.000000
# Food and drink                                   0.031873      -0.001159
# Online boarding                                  0.404074       0.001688
# Seat comfort                                     0.030014       0.003669
# Inflight entertainment                           0.047032       0.003517
# On-board service                                 0.038833      -0.028373
# Leg room service                                 0.107601      -0.005873
# Baggage handling                                 0.038762       0.002313
# Checkin service                                  0.011081      -0.035427
# Inflight service                                 0.035272       0.001681
# Cleanliness                                      0.016179      -0.003830
# Departure Delay in Minutes                      -0.006371       0.005467
# Arrival Delay in Minutes                        -0.007947       0.005178
#
#                                    Food and drink  Online boarding  \
# Age                                      0.023000         0.208939
# Flight Distance                          0.056994         0.214869
# Inflight wifi service                    0.134718         0.456970
# Departure/Arrival time convenient        0.004906         0.070119
# Ease of Online booking                   0.031873         0.404074
# Gate location                           -0.001159         0.001688
# Food and drink                           1.000000         0.234468
# Online boarding                          0.234468         1.000000
# Seat comfort                             0.574556         0.420211
# Inflight entertainment                   0.622512         0.285066
# On-board service                         0.059073         0.155443
# Leg room service                         0.032498         0.123950
# Baggage handling                         0.034746         0.083280
# Checkin service                          0.087299         0.204462
# Inflight service                         0.033993         0.074573
# Cleanliness                              0.657760         0.331517
# Departure Delay in Minutes              -0.029926        -0.018982
# Arrival Delay in Minutes                -0.032466        -0.021874
#
#                                    Seat comfort  Inflight entertainment  \
# Age                                    0.160277                0.076444
# Flight Distance                        0.157333                0.128740
# Inflight wifi service                  0.122658                0.209321
# Departure/Arrival time convenient      0.011344               -0.004861
# Ease of Online booking                 0.030014                0.047032
# Gate location                          0.003669                0.003517
# Food and drink                         0.574556                0.622512
# Online boarding                        0.420211                0.285066
# Seat comfort                           1.000000                0.610590
# Inflight entertainment                 0.610590                1.000000
# On-board service                       0.131971                0.420153
# Leg room service                       0.105559                0.299692
# Baggage handling                       0.074542                0.378210
# Checkin service                        0.191854                0.120867
# Inflight service                       0.069218                0.404855
# Cleanliness                            0.678534                0.691815
# Departure Delay in Minutes            -0.027898               -0.027489
# Arrival Delay in Minutes              -0.029735               -0.030597
#
#                                    On-board service  Leg room service  \
# Age                                        0.057594          0.040583
# Flight Distance                            0.109526          0.133916
# Inflight wifi service                      0.121500          0.160473
# Departure/Arrival time convenient          0.068882          0.012441
# Ease of Online booking                     0.038833          0.107601
# Gate location                             -0.028373         -0.005873
# Food and drink                             0.059073          0.032498
# Online boarding                            0.155443          0.123950
# Seat comfort                               0.131971          0.105559
# Inflight entertainment                     0.420153          0.299692
# On-board service                           1.000000          0.355495
# Leg room service                           0.355495          1.000000
# Baggage handling                           0.519134          0.369544
# Checkin service                            0.243914          0.153137
# Inflight service                           0.550782          0.368656
# Cleanliness                                0.123220          0.096370
# Departure Delay in Minutes                -0.031569          0.014363
# Arrival Delay in Minutes                  -0.035089          0.011924
#
#                                    Baggage handling  Checkin service  \
# Age                                       -0.047529         0.035482
# Flight Distance                            0.063184         0.073072
# Inflight wifi service                      0.120923         0.043193
# Departure/Arrival time convenient          0.072126         0.093333
# Ease of Online booking                     0.038762         0.011081
# Gate location                              0.002313        -0.035427
# Food and drink                             0.034746         0.087299
# Online boarding                            0.083280         0.204462
# Seat comfort                               0.074542         0.191854
# Inflight entertainment                     0.378210         0.120867
# On-board service                           0.519134         0.243914
# Leg room service                           0.369544         0.153137
# Baggage handling                           1.000000         0.233122
# Checkin service                            0.233122         1.000000
# Inflight service                           0.628561         0.237197
# Cleanliness                                0.095793         0.179583
# Departure Delay in Minutes                -0.005573        -0.018453
# Arrival Delay in Minutes                  -0.008576        -0.020324
#
#                                    Inflight service  Cleanliness  \
# Age                                       -0.049427     0.053611
# Flight Distance                            0.057540     0.093149
# Inflight wifi service                      0.110441     0.132698
# Departure/Arrival time convenient          0.073318     0.014292
# Ease of Online booking                     0.035272     0.016179
# Gate location                              0.001681    -0.003830
# Food and drink                             0.033993     0.657760
# Online boarding                            0.074573     0.331517
# Seat comfort                               0.069218     0.678534
# Inflight entertainment                     0.404855     0.691815
# On-board service                           0.550782     0.123220
# Leg room service                           0.368656     0.096370
# Baggage handling                           0.628561     0.095793
# Checkin service                            0.237197     0.179583
# Inflight service                           1.000000     0.088779
# Cleanliness                                0.088779     1.000000
# Departure Delay in Minutes                -0.054813    -0.014093
# Arrival Delay in Minutes                  -0.058980    -0.015732
#
#                                    Departure Delay in Minutes  \
# Age                                                 -0.010152
# Flight Distance                                      0.002158
# Inflight wifi service                               -0.017402
# Departure/Arrival time convenient                    0.001005
# Ease of Online booking                              -0.006371
# Gate location                                        0.005467
# Food and drink                                      -0.029926
# Online boarding                                     -0.018982
# Seat comfort                                        -0.027898
# Inflight entertainment                              -0.027489
# On-board service                                    -0.031569
# Leg room service                                     0.014363
# Baggage handling                                    -0.005573
# Checkin service                                     -0.018453
# Inflight service                                    -0.054813
# Cleanliness                                         -0.014093
# Departure Delay in Minutes                           1.000000
# Arrival Delay in Minutes                             0.960247
#
#                                    Arrival Delay in Minutes
# Age                                               -0.012105
# Flight Distance                                   -0.002470
# Inflight wifi service                             -0.019042
# Departure/Arrival time convenient                 -0.000918
# Ease of Online booking                            -0.007947
# Gate location                                      0.005178
# Food and drink                                    -0.032466
# Online boarding                                   -0.021874
# Seat comfort                                      -0.029735
# Inflight entertainment                            -0.030597
# On-board service                                  -0.035089
# Leg room service                                   0.011924
# Baggage handling                                  -0.008576
# Checkin service                                   -0.020324
# Inflight service                                  -0.058980
# Cleanliness                                       -0.015732
# Departure Delay in Minutes                         0.960247
# Arrival Delay in Minutes                           1.000000

# %%
correlation = raw_data.corr()
sn.heatmap(correlation, cmap='coolwarm')

# %%
import seaborn as sn

# %%
rated_variables = raw_data[['Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness']]

# %%
rated_variables
# Out:
#         Inflight wifi service  Departure/Arrival time convenient  \
# 0                           3                                  4
# 1                           3                                  2
# 2                           2                                  2
# 3                           2                                  5
# 4                           3                                  3
# ...                       ...                                ...
# 103899                      2                                  1
# 103900                      4                                  4
# 103901                      1                                  1
# 103902                      1                                  1
# 103903                      1                                  3
#
#         Ease of Online booking  Gate location  Food and drink  \
# 0                            3              1               5
# 1                            3              3               1
# 2                            2              2               5
# 3                            5              5               2
# 4                            3              3               4
# ...                        ...            ...             ...
# 103899                       2              3               2
# 103900                       4              4               2
# 103901                       1              3               4
# 103902                       1              5               1
# 103903                       3              3               1
#
#         Online boarding  Seat comfort  Inflight entertainment  \
# 0                     3             5                       5
# 1                     3             1                       1
# 2                     5             5                       5
# 3                     2             2                       2
# 4                     5             5                       3
# ...                 ...           ...                     ...
# 103899                2             2                       2
# 103900                4             5                       5
# 103901                1             5                       4
# 103902                1             1                       1
# 103903                1             1                       1
#
#         On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                      4                 3                 4                4
# 1                      1                 5                 3                1
# 2                      4                 3                 4                4
# 3                      2                 5                 3                1
# 4                      3                 4                 4                3
# ...                  ...               ...               ...              ...
# 103899                 3                 1                 4                2
# 103900                 5                 5                 5                5
# 103901                 3                 2                 4                5
# 103902                 4                 5                 1                5
# 103903                 1                 1                 4                4
#
#         Inflight service  Cleanliness
# 0                      5            5
# 1                      4            1
# 2                      4            5
# 3                      4            2
# 4                      3            3
# ...                  ...          ...
# 103899                 3            2
# 103900                 5            4
# 103901                 5            4
# 103902                 4            1
# 103903                 3            1
#
# [103904 rows x 14 columns]

# %%
short_haul_flight = raw_data.sort_values('Flight Distance').head(47978)

# %%
y = short_haul_flight.satisfaction
ydict = {'neutral or dissatisfied':0, 'satisfied':1}
y = y.map(ydict)

# %%
c = short_haul_flight.drop(columns='satisfaction')
x = c
x = pd.get_dummies(x, columns=['Gender','Customer Type', 'Type of Travel', 'Class'])

# %%
bestfeatures = SelectKBest(score_func=chi2, k=x.columns.size)
fit = bestfeatures.fit(x,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Attribute','Score']  #naming the dataframe columns
print(featureScores.nlargest(x.columns.size,'Score'))  #print the best features
# Out:
#                             Attribute         Score
# 17           Arrival Delay in Minutes  16801.948367
# 16         Departure Delay in Minutes  14585.155993
# 7                     Online boarding   5559.238318
# 24                     Class_Business   5160.925529
# 23     Type of Travel_Personal Travel   4598.411788
# 2               Inflight wifi service   3623.521126
# 0                                 Age   3284.747216
# 22     Type of Travel_Business travel   2970.116540
# 9              Inflight entertainment   2755.214378
# 25                          Class_Eco   2327.177631
# 8                        Seat comfort   1680.276848
# 1                     Flight Distance   1612.623114
# 10                   On-board service   1404.309109
# 11                   Leg room service   1388.074969
# 15                        Cleanliness   1387.474195
# 4              Ease of Online booking   1266.112321
# 6                      Food and drink    767.149026
# 13                    Checkin service    585.505670
# 21    Customer Type_disloyal Customer    566.487621
# 14                   Inflight service    485.090605
# 12                   Baggage handling    458.626555
# 20       Customer Type_Loyal Customer    179.039674
# 3   Departure/Arrival time convenient    112.711632
# 26                     Class_Eco Plus    103.695564
# 19                        Gender_Male      1.596923
# 18                      Gender_Female      1.530181
# 5                       Gate location      0.214981

# %%
pwd
# Out:
# 'C:\\Users\\user'
